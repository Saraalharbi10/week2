# %% [markdown]
# # Weekly Project 2!

# %% [markdown]
# ## Introduction to Road Traffic Accidents (RTA) Dataset
#
# ### Dataset Overview
# The RTA Dataset provides a detailed snapshot of road traffic accidents, capturing a range of data from accident conditions to casualty details. This dataset is essential for analyzing patterns and causes of accidents to improve road safety.
#
# ### Data Characteristics
# - **Entries**: The dataset contains 12,316 entries.
# - **Features**: There are 32 features in the dataset, which include:
#   - `Time`: Time when the accident occurred.
#   - `Day_of_week`: Day of the week.
#   - `Age_band_of_driver`: Age group of the driver involved.
#   - `Sex_of_driver`: Gender of the driver.
#   - `Educational_level`: Educational level of the driver.
#   - `Type_of_vehicle`: Type of vehicle involved in the accident.
#   - `Cause_of_accident`: Reported cause of the accident.
#   - `Accident_severity`: Severity of the accident.
# - **Target Column**: `Accident_severity` is used as the target column for modeling. This feature classifies the severity of each accident.
#
# ### Objective
# Students will use this dataset to apply various data visualization, modeling, and evaluation techniques learned in class. The primary goal is to build models that can accurately predict the severity of accidents and to identify the key factors that contribute to severe accidents.

# %% [markdown]
# ## Import Libraries
# Import all the necessary libraries here. Include libraries for handling data (like pandas), visualization (like matplotlib and seaborn), and modeling (like scikit-learn).

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Load Data
# Load the dataset from the provided CSV file into a DataFrame.

# %%
df = pd.read_csv('/content/weekly project/RTA_Dataset.csv')
df.head(20)
# Out:
#         Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0   17:02:00      Monday              18-30          Male   Above high school
# 1   17:02:00      Monday              31-50          Male  Junior high school
# 2   17:02:00      Monday              18-30          Male  Junior high school
# 3    1:06:00      Sunday              18-30          Male  Junior high school
# 4    1:06:00      Sunday              18-30          Male  Junior high school
# 5   14:15:00      Friday              31-50          Male                 NaN
# 6   17:30:00   Wednesday              18-30          Male  Junior high school
# 7   17:20:00      Friday              18-30          Male  Junior high school
# 8   17:20:00      Friday              18-30          Male  Junior high school
# 9   17:20:00      Friday              18-30          Male  Junior high school
# 10  14:40:00    Saturday              18-30          Male   Above high school
# 11  14:40:00    Saturday              31-50          Male   Above high school
# 12  17:45:00    Thursday              18-30          Male  Junior high school
# 13  17:45:00    Thursday              31-50          Male  Junior high school
# 14  17:45:00    Thursday              31-50          Male  Junior high school
# 15  22:45:00      Monday              18-30        Female  Junior high school
# 16  22:45:00      Monday              18-30          Male  Junior high school
# 17  22:45:00      Monday              18-30          Male   Elementary school
# 18  22:45:00      Monday              18-30          Male  Junior high school
# 19   8:20:00     Tuesday              18-30          Male  Junior high school
#
#    Vehicle_driver_relation Driving_experience       Type_of_vehicle  \
# 0                 Employee              1-2yr            Automobile
# 1                 Employee         Above 10yr   Public (> 45 seats)
# 2                 Employee              1-2yr       Lorry (41?100Q)
# 3                 Employee             5-10yr   Public (> 45 seats)
# 4                 Employee              2-5yr                   NaN
# 5                  Unknown                NaN                   NaN
# 6                 Employee              2-5yr            Automobile
# 7                 Employee              2-5yr            Automobile
# 8                 Employee         Above 10yr       Lorry (41?100Q)
# 9                 Employee              1-2yr            Automobile
# 10                   Owner              1-2yr  Public (13?45 seats)
# 11                Employee         No Licence            Automobile
# 12                Employee              1-2yr   Public (> 45 seats)
# 13                Employee             5-10yr       Lorry (41?100Q)
# 14                Employee         Above 10yr            Automobile
# 15                Employee         Above 10yr        Lorry (11?40Q)
# 16                   Owner             5-10yr  Public (13?45 seats)
# 17                Employee              2-5yr  Public (13?45 seats)
# 18                Employee              2-5yr                   NaN
# 19                Employee          Below 1yr            Long lorry
#
#    Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# 0             Owner              Above 10yr  ...   Going straight
# 1             Owner                 5-10yrs  ...   Going straight
# 2             Owner                     NaN  ...   Going straight
# 3      Governmental                     NaN  ...   Going straight
# 4             Owner                 5-10yrs  ...   Going straight
# 5               NaN                     NaN  ...           U-Turn
# 6             Owner                     NaN  ...  Moving Backward
# 7      Governmental              Above 10yr  ...           U-Turn
# 8             Owner                   1-2yr  ...   Going straight
# 9             Owner                  2-5yrs  ...           U-Turn
# 10            Owner                 Unknown  ...         Turnover
# 11            Owner                     NaN  ...   Going straight
# 12            Owner                  2-5yrs  ...   Going straight
# 13            Owner              Above 10yr  ...    Waiting to go
# 14            Owner                   1-2yr  ...   Going straight
# 15            Owner                     NaN  ...   Going straight
# 16            Owner                     NaN  ...   Going straight
# 17            Owner                     NaN  ...   Going straight
# 18            Owner              Above 10yr  ...  Moving Backward
# 19            Owner                 5-10yrs  ...   Going straight
#
#      Casualty_class Sex_of_casualty Age_band_of_casualty Casualty_severity  \
# 0                na              na                   na                na
# 1                na              na                   na                na
# 2   Driver or rider            Male                31-50                 3
# 3        Pedestrian          Female                18-30                 3
# 4                na              na                   na                na
# 5   Driver or rider            Male                31-50                 3
# 6   Driver or rider          Female                18-30                 3
# 7                na              na                   na                na
# 8        Pedestrian            Male             Under 18                 3
# 9         Passenger            Male                18-30                 3
# 10               na              na                   na                na
# 11  Driver or rider            Male                18-30                 3
# 12               na              na                   na                na
# 13               na              na                   na                na
# 14  Driver or rider          Female                18-30                 3
# 15               na              na                   na                na
# 16               na              na                   na                na
# 17               na              na                   na                na
# 18               na              na                   na                na
# 19  Driver or rider            Male             Under 18                 3
#
#    Work_of_casuality Fitness_of_casuality              Pedestrian_movement  \
# 0                NaN                  NaN                 Not a Pedestrian
# 1                NaN                  NaN                 Not a Pedestrian
# 2             Driver                  NaN                 Not a Pedestrian
# 3             Driver               Normal                 Not a Pedestrian
# 4                NaN                  NaN                 Not a Pedestrian
# 5             Driver               Normal                 Not a Pedestrian
# 6             Driver               Normal                 Not a Pedestrian
# 7                NaN               Normal                 Not a Pedestrian
# 8             Driver               Normal  Crossing from driver's nearside
# 9             Driver               Normal                 Not a Pedestrian
# 10               NaN               Normal                 Not a Pedestrian
# 11            Driver               Normal                 Not a Pedestrian
# 12            Driver               Normal                 Not a Pedestrian
# 13             Other               Normal                 Not a Pedestrian
# 14            Driver               Normal                 Not a Pedestrian
# 15               NaN                  NaN                 Not a Pedestrian
# 16            Driver               Normal                 Not a Pedestrian
# 17            Driver               Normal                 Not a Pedestrian
# 18        Unemployed               Normal                 Not a Pedestrian
# 19            Driver               Normal                 Not a Pedestrian
#
#              Cause_of_accident Accident_severity
# 0              Moving Backward     Slight Injury
# 1                   Overtaking     Slight Injury
# 2    Changing lane to the left    Serious Injury
# 3   Changing lane to the right     Slight Injury
# 4                   Overtaking     Slight Injury
# 5                  Overloading     Slight Injury
# 6                        Other     Slight Injury
# 7       No priority to vehicle     Slight Injury
# 8   Changing lane to the right     Slight Injury
# 9              Moving Backward    Serious Injury
# 10   Changing lane to the left    Serious Injury
# 11   No priority to pedestrian    Serious Injury
# 12               No distancing     Slight Injury
# 13      No priority to vehicle     Slight Injury
# 14               No distancing    Serious Injury
# 15               No distancing    Serious Injury
# 16             Moving Backward     Slight Injury
# 17  Changing lane to the right    Serious Injury
# 18   No priority to pedestrian     Slight Injury
# 19             Moving Backward    Serious Injury
#
# [20 rows x 32 columns]

# %%
df.sample(10)
# Out:
#           Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 2397  17:35:00   Wednesday            Over 51          Male
# 2195  15:50:00    Thursday              31-50          Male
# 297   17:21:00    Thursday              31-50          Male
# 4787  12:45:00     Tuesday            Over 51          Male
# 8071  16:15:00    Saturday              18-30          Male
# 997   19:08:00    Thursday              18-30          Male
# 5103  12:04:00      Monday            Over 51          Male
# 2459  15:45:00    Saturday              31-50          Male
# 3864  15:50:00   Wednesday            Unknown       Unknown
# 6280  17:21:00    Thursday              18-30          Male
#
#        Educational_level Vehicle_driver_relation Driving_experience  \
# 2397  Junior high school                Employee         Above 10yr
# 2195   Elementary school                Employee             5-10yr
# 297   Junior high school                   Owner              2-5yr
# 4787  Junior high school                Employee             5-10yr
# 8071  Junior high school                Employee          Below 1yr
# 997   Junior high school                Employee             5-10yr
# 5103  Junior high school                   Owner         Above 10yr
# 2459  Junior high school                Employee              2-5yr
# 3864  Junior high school                Employee              2-5yr
# 6280  Junior high school                   Owner             5-10yr
#
#      Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 2397           Other            Owner              Above 10yr  ...
# 2195      Automobile            Owner                     NaN  ...
# 297       Automobile            Owner                     NaN  ...
# 4787      Long lorry            Owner                     NaN  ...
# 8071           Other            Owner                  2-5yrs  ...
# 997              NaN            Owner              Above 10yr  ...
# 5103      Automobile            Owner                 Unknown  ...
# 2459  Lorry (11?40Q)            Owner                 Unknown  ...
# 3864             NaN            Owner                     NaN  ...
# 6280      Automobile            Owner                     NaN  ...
#
#      Vehicle_movement Casualty_class Sex_of_casualty Age_band_of_casualty  \
# 2397   Going straight             na              na                   na
# 2195   Going straight             na              na                   na
# 297            Parked             na              na                   na
# 4787      Getting off             na              na                   na
# 8071   Going straight             na              na                   na
# 997          Stopping             na              na                   na
# 5103   Going straight             na              na                   na
# 2459   Going straight             na              na                   na
# 3864  Moving Backward             na              na                   na
# 6280   Going straight      Passenger          Female             Under 18
#
#      Casualty_severity Work_of_casuality Fitness_of_casuality  \
# 2397                na               NaN               Normal
# 2195                na            Driver               Normal
# 297                 na          Employee               Normal
# 4787                na            Driver                 Deaf
# 8071                na               NaN                  NaN
# 997                 na            Driver               Normal
# 5103                na          Employee               Normal
# 2459                na            Driver                Blind
# 3864                na            Driver               Normal
# 6280                 3               NaN               Normal
#
#      Pedestrian_movement                     Cause_of_accident  \
# 2397    Not a Pedestrian                    Driving carelessly
# 2195    Not a Pedestrian                         No distancing
# 297     Not a Pedestrian                    Driving carelessly
# 4787    Not a Pedestrian  Driving under the influence of drugs
# 8071    Not a Pedestrian            Changing lane to the right
# 997     Not a Pedestrian                                 Other
# 5103    Not a Pedestrian             Changing lane to the left
# 2459    Not a Pedestrian  Driving under the influence of drugs
# 3864    Not a Pedestrian                No priority to vehicle
# 6280    Not a Pedestrian            Changing lane to the right
#
#      Accident_severity
# 2397     Slight Injury
# 2195     Slight Injury
# 297      Slight Injury
# 4787     Slight Injury
# 8071    Serious Injury
# 997     Serious Injury
# 5103    Serious Injury
# 2459     Slight Injury
# 3864     Slight Injury
# 6280     Slight Injury
#
# [10 rows x 32 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9023 entries, 0 to 9022
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         9023 non-null   object
#  1   Day_of_week                  9023 non-null   object
#  2   Age_band_of_driver           9023 non-null   object
#  3   Sex_of_driver                9023 non-null   object
#  4   Educational_level            8501 non-null   object
#  5   Vehicle_driver_relation      8645 non-null   object
#  6   Driving_experience           8423 non-null   object
#  7   Type_of_vehicle              8306 non-null   object
#  8   Owner_of_vehicle             8669 non-null   object
#  9   Service_year_of_vehicle      6055 non-null   object
#  10  Defect_of_vehicle            5727 non-null   object
#  11  Area_accident_occured        8846 non-null   object
#  12  Lanes_or_Medians             8728 non-null   object
#  13  Road_allignment              8910 non-null   object
#  14  Types_of_Junction            9023 non-null   object
#  15  Road_surface_type            8896 non-null   object
#  16  Road_surface_conditions      9022 non-null   object
#  17  Light_conditions             9022 non-null   object
#  18  Weather_conditions           9022 non-null   object
#  19  Type_of_collision            8917 non-null   object
#  20  Number_of_vehicles_involved  9022 non-null   float64
#  21  Number_of_casualties         9022 non-null   float64
#  22  Vehicle_movement             8811 non-null   object
#  23  Casualty_class               9022 non-null   object
#  24  Sex_of_casualty              9022 non-null   object
#  25  Age_band_of_casualty         9022 non-null   object
#  26  Casualty_severity            9022 non-null   object
#  27  Work_of_casuality            6666 non-null   object
#  28  Fitness_of_casuality         7072 non-null   object
#  29  Pedestrian_movement          9022 non-null   object
#  30  Cause_of_accident            9022 non-null   object
#  31  Accident_severity            9022 non-null   object
# dtypes: float64(2), object(30)
# memory usage: 2.2+ MB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               522
# Vehicle_driver_relation         378
# Driving_experience              600
# Type_of_vehicle                 717
# Owner_of_vehicle                354
# Service_year_of_vehicle        2968
# Defect_of_vehicle              3296
# Area_accident_occured           177
# Lanes_or_Medians                295
# Road_allignment                 113
# Types_of_Junction                 0
# Road_surface_type               127
# Road_surface_conditions           1
# Light_conditions                  1
# Weather_conditions                1
# Type_of_collision               106
# Number_of_vehicles_involved       1
# Number_of_casualties              1
# Vehicle_movement                212
# Casualty_class                    1
# Sex_of_casualty                   1
# Age_band_of_casualty              1
# Casualty_severity                 1
# Work_of_casuality              2357
# Fitness_of_casuality           1951
# Pedestrian_movement               1
# Cause_of_accident                 1
# Accident_severity                 1
# dtype: int64

# %%
columns_to_drop = ['Work_of_casuality', 'Fitness_of_casuality']

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
# Perform EDA to understand the data better. This involves several steps to summarize the main characteristics, uncover patterns, and establish relationships:
# * Find the dataset information and observe the datatypes.
# * Check the shape of the data to understand its structure.
# * View the the data with various functions to get an initial sense of the data.
# * Perform summary statistics on the dataset to grasp central tendencies and variability.
# * Check for duplicated data.
# * Check for null values.
#
# And apply more if needed!

# %%
plt.hist(df['Number_of_vehicles_involved']);

# %%
df.corr(numeric_only=True)
# Out:
#                              Number_of_vehicles_involved  Number_of_casualties
# Number_of_vehicles_involved                      1.00000               0.21956
# Number_of_casualties                             0.21956               1.00000

# %%
df.describe()
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# count                  9022.000000           9022.000000
# mean                      2.020284              1.522833
# std                       0.643135              1.003530
# min                       1.000000              1.000000
# 25%                       2.000000              1.000000
# 50%                       2.000000              1.000000
# 75%                       2.000000              2.000000
# max                       7.000000              8.000000

# %% [markdown]
# ## Data Preprocessing
# Data preprocessing is essential for transforming raw data into a format suitable for further analysis and modeling. Follow these steps to ensure your data is ready for predictive modeling or advanced analytics:
# - **Handling Missing Values**: Replace missing values with appropriate statistics (mean, median, mode) or use more complex imputation techniques.
# - **Normalization/Scaling**: Scale data to a small, specified range like 0 to 1, or transform it to have a mean of zero and a standard deviation of one.
# - **Label Encoding**: Convert categorical text data into model-understandable numbers where the labels are ordered.
# - **One-Hot Encoding**: Use for nominal categorical data where no ordinal relationship exists to transform the data into a binary column for each category. (Be careful not to increase the dimensionality significantly)
# - **Detection and Treatment of Outliers**: Use statistical tests, box plots, or scatter plots to identify outliers and then cap, trim, or use robust methods to reduce the effect of outliers, depending on the context.
# - **Feature Engineering**: Enhance your dataset by creating new features and transforming existing ones. This might involve combining data from different columns, applying transformations, or reducing dimensionality with techniques like PCA to improve model performance.
#
# Consider these steps as a foundation, and feel free to introduce additional preprocessing techniques as needed to address specific characteristics of your dataset.

# %%
sns.boxplot(df[['Number_of_casualties']]);

# %% [markdown]
# ## Data Visualization
# Create various plots to visualize the relationships in the data. Consider using the following to show different aspects of the data:
#
# * Heatmap of Correlation Matrix.
# * Line plots.
# * Scatter plots.
# * Histograms.
# * Boxplots.
#
# Use more if needed!

# %%
sns.scatterplot(x='Number_of_vehicles_involved',y='Number_of_casualties',data=df);

# %%
sns.pairplot(df);

# %% [markdown]
# ## Feature Selection
# - Choose features that you believe will most influence the outcome based on your analysis and the insights from your visualizations. Focus on those that appear most impactful to include in your modeling.
#
# ## Train-Test Split
# * Divide the dataset into training and testing sets to evaluate the performance of your models.

# %%
x=df.drop('Number_of_vehicles_involved',axis=1)
y=df['Number_of_vehicles_involved']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train ,x_test ,y_train ,y_test =train_test_split(x,y,
                                                  test_size=0.4,
                                                  random_state=23)

# %%
df.shape
# Out:
# (9023, 32)

# %%
x_train.shape
# Out:
# (5413, 31)

# %% [markdown]
# ## Modeling
#
# Once the data is split into training and testing sets, the next step is to build models to make predictions. Here, we will explore several machine learning algorithms, each with its unique characteristics and suitability for different types of data and problems. You will implement the following models:
#
# ### 1. Logistic Regression
#
# ### 2. Decision Tree Classifier
#
# ### 3. Support Vector Machine (SVM)
#
# ### 4. K-Neighbors Classifier
#
# ### Implementing the Models
# - For each model, use the training data you have prepared to train the model.

# %% [markdown]
# #### Logistic Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm=(y_train,x_train);

# %%
y_test
# Out:
# 1837    2.0
# 290     2.0
# 6879    2.0
# 6600    2.0
# 3146    2.0
#        ...
# 5509    2.0
# 6393    2.0
# 691     2.0
# 4879    2.0
# 4709    1.0
# Name: Number_of_vehicles_involved, Length: 3610, dtype: float64

# %% [markdown]
# #### Decision Tree Classifier

# %% [markdown]
# #### Support Vector Machine (SVM)

# %%
pr=lm.predict(x_test)
pr

# %% [markdown]
# #### K-Neighbors Classifier

# %%
from sklearn.impute import KNNImputer


imputer = KNNImputer()

imputer.fit(Number_of_casualties)
Number_of_casualties=imputer.transform(Number_of_casualties )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-164-56299499fd1f> in <cell line: 6>()
#       4 imputer = KNNImputer()
#       5
# ----> 6 imputer.fit(Number_of_casualties)
#       7 Number_of_casualties=imputer.transform(Number_of_casualties )
#       8
#
# NameError: name 'Number_of_casualties' is not defined

# %% [markdown]
# ## Model Evaluation
#
# After training your models, it's crucial to evaluate their performance to understand their effectiveness and limitations. This section outlines various techniques and metrics to assess the performance of each model you have implemented.
#
# ### Evaluation Techniques
# 1. **Confusion Matrix**
#
# 2. **Accuracy**
#
# 3. **Precision and Recall**
#
# 4. **F1 Score**
#
# 5. **ROC Curve and AUC**
#
# ### Implementing Evaluation
# - Calculate the metrics listed above using your test data.

# %%
from sklearn import metrics

# %%
metrics.mean_absolute_error(y_test,Number_of_vehicles_involved)

# %%
metrics.mean_squared_error(y_test,Number_of_vehicles_involved)

# %%
np.sqrt (metrics.mean_squared_error(y_test,Number_of_vehicles_involved))

# %%
metrics.r2_score(y_test,Number_of_vehicles_involved)

# %% [markdown]
# ## Project Questions:
#
# ### Comparative Analysis
#
# - **Compare Metrics**: Examine the performance metrics (such as accuracy, precision, and recall) of each model. Document your observations on which model performs best for your dataset and the problem you're addressing.
# - **Evaluate Trade-offs**: Discuss the trade-offs you encountered when choosing between models. Consider factors like computational efficiency, ease of implementation, and model interpretability.
# - **Justify Your Choice**: After comparing and evaluating, explain why you believe one model is the best choice. Provide a clear rationale based on the performance metrics and trade-offs discussed.
# - **Feature Importance**: Identify and discuss the most important features for the best-performing model. How do these features impact the predictions? Use the visualizations you have created to justify your answer if necessary.
# - **Model Limitations**: Discuss any limitations you encountered with the models you used. Are there any aspects of the data or the problem that these models do not handle well?
# - **Future Improvements**: Suggest potential improvements or further steps you could take to enhance model performance. This could include trying different algorithms, feature engineering techniques, or tuning hyperparameters.

# %% [markdown]
# ### Answer Here:
